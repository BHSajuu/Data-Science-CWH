# %%
import matplotlib.pyplot as plt
plt.style.use("seaborn-v0_8-dark-palette")

# %%
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]
plt.title("Career Runs of Indian Batsmen")
plt.pie(runs, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c73a43ee10>,
#   <matplotlib.patches.Wedge at 0x1c73a6c7f20>,
#   <matplotlib.patches.Wedge at 0x1c73a7a7260>,
#   <matplotlib.patches.Wedge at 0x1c73a7a7650>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(runs, labels=labels, colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c73a9893d0>,
#   <matplotlib.patches.Wedge at 0x1c73a7fd640>,
#   <matplotlib.patches.Wedge at 0x1c73a989b20>,
#   <matplotlib.patches.Wedge at 0x1c73a989f10>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
plt.pie(
 runs,
 labels=labels,
 colors=colors,
 wedgeprops={'edgecolor': 'black', 'linewidth': 2, 'linestyle': '--'}
)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c73a9e8170>,
#   <matplotlib.patches.Wedge at 0x1c73a6c7e00>,
#   <matplotlib.patches.Wedge at 0x1c73a9e88f0>,
#   <matplotlib.patches.Wedge at 0x1c73a9e8bc0>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
explode = [0.1, 0, 0, 0] # Only highlight Sachin's slice
plt.pie(runs, labels=labels, explode=explode, colors=colors)
plt.title("Exploded Pie Example")
# Out:
# Text(0.5, 1.0, 'Exploded Pie Example')

# %%
plt.pie(
 runs,
 labels=labels,
 explode=explode,
 colors=colors,
 shadow=True, # adds a 3D-like shadow
 autopct='%1.1f%%',
)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c73a453410>,
#   <matplotlib.patches.Wedge at 0x1c73a8763f0>,
#   <matplotlib.patches.Wedge at 0x1c73a896420>,
#   <matplotlib.patches.Wedge at 0x1c73a9e9fd0>],
#  [Text(0.44543666795344244, 1.1142648584795876, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')],
#  [Text(0.25983805630617474, 0.6499878341130926, '37.9%'),
#   Text(-0.5839959690662998, 0.13765430655926977, '16.8%'),
#   Text(-0.2768046510943666, -0.5323337159456707, '25.3%'),
#   Text(0.4854102263424771, -0.3526711104728386, '20.0%')])
